# %%
# File Management and Archiving
import os
import glob
import shutil
import zipfile

# Data Processing with PySpark
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import (StructType, StructField, StringType,
                               IntegerType, FloatType, TimestampType,
                               LongType)

# %% [markdown]
# <div style="background-color:#000000 ; padding: 10px 0;">
#     <center><h1 style="color: white; font-weight:bold">FILE EXTRACTION</h1></center>
# </div>

# %% [markdown]
# Only certain files in the directory will be utilized. We will first extract these files then unzip them later.

# %%
def copy_files(destination_dir, search_pattern, start_date, end_date):
    """
    Copy files from a source directory to a target directory based on a date
    range.

    Parameters
    ----------
    destination_dir : str
        The path to the directory where the files should be copied.
    search_pattern : str
        The glob pattern to locate the source files (full path).
    start_date : str
        The earliest date to include in the filtering (format: YYYYMMDD).
    end_date : str
        The latest date to include in the filtering (format: YYYYMMDD).
    """
    os.makedirs(destination_dir, exist_ok=True)
    source_dir = "/mnt/data/public/gdeltv2/gkg"
    target_dir = destination_dir

    # Find all files matching the search_pattern
    all_files = glob.glob(search_pattern)

    # Initialize an empty list to collect matching files
    filtered_files = []

    # Iterate through the matched files and filter by the desired date range
    for file in all_files:
        # Extract the base file name without path
        base_name = os.path.basename(file)
        
        # Extract the date portion (first 8 characters) of the base name
        file_date = base_name[:8]
        
        # Check if the file date falls within the specified range
        if start_date <= file_date <= end_date:
            filtered_files.append(file)
    
    # Copy each filtered file to the target directory
    for file in filtered_files:
        shutil.copy(file, target_dir)
        print(f"Copied: {file} to {destination_dir}")

# Copy files 
# 2016-10-02 to 2016-10-08
copy_files('/home/msds2024/xx/cptxx_shared/data_2016',
           '/mnt/data/public/gdeltv2/gkg/201510*.gkg.csv.zip',
           '20161002', '20161008')

# 2015-10-02 to 2015-10-08
copy_files('/home/msds2024/xx/cptx_shared/data_2015',
           '/mnt/data/public/gdeltv2/gkg/201510*.gkg.csv.zip',
           '20151002', '20151008')
# Out:
# Copied: /mnt/data/public/gdeltv2/gkg/20151002130000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005004500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004104500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008024500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006184500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005140000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003213000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007040000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004094500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005061500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003101500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002091500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004150000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006151500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006064500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003184500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007183000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002071500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008120000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007180000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005030000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005011500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004081500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004151500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007151500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006061500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005104500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008130000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006130000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008063000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004034500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003004500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003153000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002131500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008061500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008010000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004143000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007074500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007164500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006204500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003080000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005184500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004224500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006193000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008163000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003040000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004060000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003231500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005103000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007173000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005194500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003180000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004000000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002114500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004040000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007083000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008190000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007214500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003173000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006003000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008204500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008093000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008161500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002113000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005141500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008151500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006231500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003234500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006194500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004014500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002121500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008021500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003131500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008094500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006113000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002234500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003083000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002011500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006211500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005114500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004080000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005174500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006101500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003111500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008114500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003023000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005200000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006000000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007211500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003160000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004093000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006233000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007174500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002033000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005193000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003050000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003130000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005173000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004160000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005073000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008233000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005051500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004140000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007101500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004070000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008003000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008050000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002200000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008150000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004061500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002044500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007111500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007084500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002143000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008231500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005120000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003134500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006104500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005190000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006023000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007121500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005223000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008164500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006094500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004194500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004030000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006224500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151
.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008100000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004050000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008074500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005230000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002053000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002060000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004003000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008223000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002064500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002210000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002030000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007161500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006121500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005201500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004031500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005091500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007124500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003084500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006073000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006180000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002220000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006133000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003194500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008191500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007170000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005054500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005044500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005154500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003191500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007070000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002211500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007203000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008144500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002014500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007051500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006040000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006054500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008071500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004074500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005041500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004124500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006124500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004191500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006150000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004051500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004231500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004023000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004103000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007080000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008141500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007004500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004123000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003011500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005183000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007230000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005003000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002191500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007160000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004233000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005171500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008200000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002041500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006181500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151004044500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005213000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008183000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151008000000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003221500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006063000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151002193000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151007054500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151003051500.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005063000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151005233000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015
# Copied: /mnt/data/public/gdeltv2/gkg/20151006100000.gkg.csv.zip to /home/msds2024/pmartinez/cpt1_shared/data_2015

# %% [markdown]
# <div style="background-color:#000000 ; padding: 10px 0;">
#     <center><h1 style="color: white; font-weight:bold">UNZIP THE FILES</h1></center>
# </div>

# %%
def unzip_files(source_dir, destination_dir, pattern):
    """
    Extract ZIP files from a source directory to a destination directory.

    Parameters
    ----------
    source_dir : str
        The path to the directory containing the ZIP files.
    destination_dir : str
        The path to the directory where the extracted files should be saved.
    pattern : str
        The glob pattern to locate the ZIP files (e.g., "*.zip").
    """
    # Create the output directory if it doesn't exist
    os.makedirs(destination_dir, exist_ok=True)

    # Get a list of all files matching the pattern
    zip_files = glob.glob(os.path.join(source_dir, pattern))

    # Extract each zip file to the destination directory
    for zip_filepath in zip_files:
        with zipfile.ZipFile(zip_filepath, 'r') as zip_ref:
            zip_ref.extractall(destination_dir)
    print(f"Extraction completed. Files were extracted to: {destination_dir}")

# Unzip the 2015 and 2016 zip files
unzip_files('/home/msds2024/xx/cptx_shared/data_2015',
            '/home/msds2024/xx/cptx_shared/slt1a/bdcc/201510',
            '*.gkg.csv.zip')

unzip_files('/home/msds2024/xx/cptx_shared/data_2016',
            '/home/msds2024/xx/cptx_shared/slt1x/bdcc/201610',
            '*.gkg.csv.zip')
# Out:
# Extraction completed. Files were extracted to: /home/msds2024/pmartinez/cpt1_shared/slt1a/bdcc/201510

# %% [markdown]
# <div style="background-color:#000000 ; padding: 10px 0;">
#     <center><h1 style="color: white; font-weight:bold">CHECK TOTAL FILE SIZE</h1></center>
# </div>

# %%
def check_file_size(directory):
    """
    Calculate and print the total size of all files (in GB) in a specified
    directory.

    Parameters
    ----------
    directory : str
        The path to the directory whose total file size is to be calculated.
    """
    total_size = 0

    # List all items in the specified directory (only the top level)
    for item in os.listdir(directory):
        # Get the full path of the item
        item_path = os.path.join(directory, item)
        
        # Check if the item is a file, and add its size if it is
        if os.path.isfile(item_path):
            total_size += os.path.getsize(item_path)

    # Convert the size to gigabytes (GB)
    total_size_gb = total_size / (1024 * 1024 * 1024)
    
    # Print out the total size in GB
    print(f"Total size of files in '{directory}': {total_size_gb:.2f} GB")

check_file_size('/home/msds2024/xx/cptx_shared/sltxx/bdcc/201510')
check_file_size('/home/msds2024/xx/cptx_shared/sltxx/bdcc/201610')
# Out:
# Total size of files in '/home/msds2024/pmartinez/cpt1_shared/slt1a/bdcc/201510': 17.80 GB
# Total size of files in '/home/msds2024/pmartinez/cpt1_shared/slt1a/bdcc/201610': 23.99 GB

# %% [markdown]
# <div style="background-color:#000000 ; padding: 10px 0;">
#     <center><h1 style="color: white; font-weight:bold">CONVERT CSV TO PARQUET</h1></center>
# </div>

# %%
spark = (SparkSession
     .builder
     .master('local[*]') # Master URL;
     .getOrCreate())

# %%
def convert_to_parquet(csv_filepath, output_path, file_pattern):
    """
    Convert a set of CSV files to Parquet format based on a given schema and
    pattern.

    Parameters
    ----------
    csv_filepath : str
        The path to the directory containing the source CSV files.
    output_path : str
        The directory where the Parquet files should be written.
    file_pattern : str
        The glob pattern used to locate the relevant CSV files.
    """
    os.makedirs(output_path, exist_ok=True)
    schema = StructType([
        StructField("GKGRECORDID", StringType(), True),
        StructField("V2.1DATE", LongType(), True),
        StructField("V2SOURCECOLLECTIONIDENTIFIER", IntegerType(), True),
        StructField("V2SOURCECOMMONNAME", StringType(), True),
        StructField("V2DOCUMENTIDENTIFIER", StringType(), True),
        StructField("V1COUNTS", StringType(), True),
        StructField("V2.1COUNTS", StringType(), True),
        StructField("V1THEMES", StringType(), True),
        StructField("V2ENHANCEDTHEMES", StringType(), True),
        StructField("V1LOCATIONS", StringType(), True),
        StructField("V2ENHANCEDLOCATIONS", StringType(), True),
        StructField("V1PERSONS", StringType(), True),
        StructField("V2ENHANCEDPERSONS", StringType(), True),
        StructField("V1ORGANIZATIONS", StringType(), True),
        StructField("V2ENHANCEDORGANIZATIONS", StringType(), True),
        StructField("V1.5TONE", StringType(), True),
        StructField("V2.1ENHANCEDDATES", StringType(), True),
        StructField("V2GCAM", StringType(), True),
        StructField("V2.1SHARINGIMAGE", StringType(), True),
        StructField("V2.1RELATEDIMAGES", StringType(), True),
        StructField("V2.1SOCIALIMAGEEMBEDS", StringType(), True),
        StructField("V2.1SOCIALVIDEOEMBEDS", StringType(), True),
        StructField("V2.1QUOTATIONS", StringType(), True),
        StructField("V2.1ALLNAMES", StringType(), True),
        StructField("V2.1AMOUNTS", StringType(), True),
        StructField("V2.1TRANSLATIONINFO", StringType(), True),
        StructField("V2EXTRASXML", StringType(), True)
    ])
    search_path = os.path.join(csv_filepath, file_pattern)
    
    # List all files matching the pattern
    files = glob.glob(search_path)
    df = spark.read.csv(files, sep='\t', schema=schema)

    # Write the DataFrame to Parquet format
    df.write.parquet(output_path, mode='overwrite')

# Convert 2015 CSVs to parquet
convert_to_parquet("/home/msds2024/xx/cptx_shared/sltxx/bdcc/201510",
                   "/home/msds2024/xx/cptx_shared/sltxx/bdcc/"\
                   "201510/parquets",
                   "201510*.gkg.csv")

# Convert 2016 CSVs to parquet
convert_to_parquet("/home/msds2024/xx/cptx_shared/sltxx/bdcc/201610",
                   "/home/msds2024/xx/cptx_shared/sltxx/bdcc/"\
                   "201610/parquets",
                   "201610*.gkg.csv")
